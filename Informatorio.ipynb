# %% [markdown]
# Cargamos librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Cargamos datos

# %%
births = pd.read_csv('nacimientos_por_departamento.csv')
names_frequency = pd.read_csv('nombres_propios.csv')

# %% [markdown]
# Mostrar las primeras y últimas filas

# %%
births.head()
# Out:
#    provincia_id provincia_nombre  departamento_id     departamento_nombre  \
# 0           6.0     Buenos Aires           6854.0              25 de Mayo
# 1           6.0     Buenos Aires           6588.0              9 de Julio
# 2           6.0     Buenos Aires           6007.0           Adolfo Alsina
# 3           6.0     Buenos Aires           6014.0  Adolfo Gonzales Chaves
# 4           6.0     Buenos Aires           6021.0                 Alberti
#
#    anio  nacimientos_cantidad  poblacion_total    tbn
# 0  2012                   575            36343  15.82
# 1  2012                   716            48283  14.83
# 2  2012                   220            17276  12.73
# 3  2012                   159            12116  13.12
# 4  2012                   125            10799  11.58

# %%
births.tail()
# Out:
#       provincia_id  provincia_nombre  departamento_id departamento_nombre  \
# 5638          94.0  Tierra del Fuego          94008.0          Río Grande
# 5639          94.0  Tierra del Fuego          94008.0          Río Grande
# 5640          94.0  Tierra del Fuego          94008.0          Río Grande
# 5641          94.0  Tierra del Fuego          94008.0          Río Grande
# 5642          94.0  Tierra del Fuego          94008.0          Río Grande
#
#       anio  nacimientos_cantidad  poblacion_total    tbn
# 5638  2018                  1535            86222  17.80
# 5639  2019                  1318            89117  14.79
# 5640  2020                  1057            92118  11.47
# 5641  2021                   915            95211   9.61
# 5642  2022                   795            98408   8.08

# %%
names_frequency.head()
# Out:
#    provincia_id nombre_provincia     nombre  anio sexo  cantidad
# 0             6     Buenos Aires     JAZMIN  2012    F      8501
# 1             6     Buenos Aires  VALENTINA  2012    F      5911
# 2             6     Buenos Aires        MIA  2012    F      5879
# 3             6     Buenos Aires      SOFIA  2012    F      4616
# 4             6     Buenos Aires       ALMA  2012    F      4597

# %%
names_frequency.tail()
# Out:
#        provincia_id nombre_provincia   nombre  anio sexo  cantidad
# 11995            99       Total país    TOMAS  2023    M      3764
# 11996            99       Total país     CIRO  2023    M      3667
# 11997            99       Total país  GABRIEL  2023    M      3636
# 11998            99       Total país  BENICIO  2023    M      3592
# 11999            99       Total país  JOAQUIN  2023    M      3585

# %% [markdown]
# Ver caracteristicas de los archivos

# %%
#Informacion basica de los dataframes
births.info()
print("-----------------------------------------------------------")
names_frequency.info()
print("-----------------------------------------------------------")
#Informacion de las caracteristicas del datafarame en referencia a sus columnas y filas
print("El df births posee (rows/columns) " + str(births.shape))
print("El df names_frequency posee (rows/columns) " + str(names_frequency.shape))
print("-----------------------------------------------------------")

#Nombres de las columnas que posee cada dataframe
print(names_frequency.columns)
print("-----------------------------------------------------------")
print(births.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5643 entries, 0 to 5642
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   provincia_id          5632 non-null   float64
#  1   provincia_nombre      5643 non-null   object
#  2   departamento_id       5621 non-null   float64
#  3   departamento_nombre   5632 non-null   object
#  4   anio                  5643 non-null   int64
#  5   nacimientos_cantidad  5643 non-null   int64
#  6   poblacion_total       5643 non-null   int64
#  7   tbn                   5643 non-null   float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 352.8+ KB
# -----------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
# ...

# %% [markdown]
# Estadistica general de los Dataframe

# %%
print(names_frequency.describe())
print("-----------------------------------------------------------")
print(births.describe())
# Out:
#        provincia_id          anio      cantidad
# count  12000.000000  12000.000000  12000.000000
# mean      50.040000   2017.500000    686.078250
# std       28.912766      3.452196   1885.373229
# min        2.000000   2012.000000     10.000000
# 25%       26.000000   2014.750000     96.000000
# 50%       50.000000   2017.500000    190.000000
# 75%       74.000000   2020.250000    376.000000
# max       99.000000   2023.000000  33181.000000
# -----------------------------------------------------------
#        provincia_id  departamento_id         anio  nacimientos_cantidad  \
# count   5632.000000      5621.000000  5643.000000           5643.000000
# mean      37.421875     37661.622309  2017.000000           1287.120858
# std       28.768476     28643.194749     3.162558           2870.296846
# min        2.000000      6007.000000  2012.000000              0.000000
# 25%        6.000000      6833.000000  2014.000000            173.500000
# ...

# %% [markdown]
# **Limpieza general de los datos**

# %% [markdown]
# > Eliminacion de columnas inecesarias

# %%
#Eliminar columnas inecesarias del df names_frequency
names_frequency.drop(columns=['provincia_id'], inplace=True)
#Eliminar columnas inecesarias del df births
births.drop(columns=['provincia_id',"departamento_id","tbn"], inplace=True)

# %% [markdown]
# > Mostrar si los dataframe poseen datos nulos o NaN

# %%
print(births.isnull().sum())
print("-----------------------------------------------------------")
print(births.isna().sum())
print("-----------------------------------------------------------")
print("-----------------------------------------------------------")
print(names_frequency.isnull().sum())
print("-----------------------------------------------------------")
print(names_frequency.isna().sum())
# Out:
# provincia_nombre         0
# departamento_nombre     11
# anio                     0
# nacimientos_cantidad     0
# poblacion_total          0
# dtype: int64
# -----------------------------------------------------------
# provincia_nombre         0
# departamento_nombre     11
# anio                     0
# nacimientos_cantidad     0
# poblacion_total          0
# dtype: int64
# -----------------------------------------------------------
# -----------------------------------------------------------
# nombre_provincia    0
# nombre              0
# anio                0
# sexo                0
# cantidad            0
# dtype: int64
# -----------------------------------------------------------
# nombre_provincia    0
# nombre              0
# anio                0
# sexo                0
# cantidad            0
# dtype: int64

# %% [markdown]
# > Eliminar datos duplicados de cada dataframe

# %%
births.drop_duplicates(inplace=True)
names_frequency.drop_duplicates(inplace=True)

# %% [markdown]
# > Eliminar datos nulos o invalidos

# %%
#Ambos dataframe possen 11 registros que son nulos o invalidos, por ese motivos se procede a la eliminacion ya que ambos cuentan con muchos registros
#y no afectaria la estadistica en general
births.dropna(inplace=True)
names_frequency.dropna(inplace=True)

# %% [markdown]
# > Corroboramos que se eliminó los datos

# %%
print(births.isnull().sum())
print("-----------------------------------------------------------")
print(births.isna().sum())
print("-----------------------------------------------------------")
print("-----------------------------------------------------------")
print(names_frequency.isnull().sum())
print("-----------------------------------------------------------")
print(names_frequency.isna().sum())
# Out:
# provincia_nombre        0
# departamento_nombre     0
# anio                    0
# nacimientos_cantidad    0
# poblacion_total         0
# dtype: int64
# -----------------------------------------------------------
# provincia_nombre        0
# departamento_nombre     0
# anio                    0
# nacimientos_cantidad    0
# poblacion_total         0
# dtype: int64
# -----------------------------------------------------------
# -----------------------------------------------------------
# nombre_provincia    0
# nombre              0
# anio                0
# sexo                0
# cantidad            0
# dtype: int64
# -----------------------------------------------------------
# nombre_provincia    0
# nombre              0
# anio                0
# sexo                0
# cantidad            0
# dtype: int64

# %% [markdown]
# # **VISUALIZACION DE DATOS**

# %% [markdown]
# Para el siguiente analisis tomamos como referencia los nacimientos ocurridos en Argentina durante los años del 2012 al 2022. Tambien agregamos datos del tipo de sexo ocurridos en esos nacimientos.

# %% [markdown]
# **Grafico 1:** En el siguiente grafico podemos apreciar la cantidad de nacimientos durante las fechas mencionadas. Podemos ver que del 2012 al 2014 un leve acenso en los nacimientos y a partir de esa fecha una decrecimiento considerable.

# %%
df = births.groupby('anio').sum()
plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")

sns.lineplot(data=df, x="anio", y='nacimientos_cantidad',palette='crest')
plt.xlabel('Año')
plt.xticks(ticks=range(2012,2023,1))
plt.yticks(ticks=range(440000,800000,20000))
plt.ylabel('Nacimientos')
plt.title('Nacimientos por Año')
plt.show()
# Out:
# /tmp/ipython-input-12-4133462906.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data=df, x="anio", y='nacimientos_cantidad',palette='crest')

# %% [markdown]
# **Grafico 2:**En el siguiente grafico podemos apreciar en los nacimiento que genero en cuention se le atribuyo. Podemos apreciar que en el rango de años del 2012 al 2022 el sexo masculumo tuvo 4.000.000 nacimiento contra aproximadamente 3.700.000, que corresponden al sexo masculino 52,4% y el sexo femenino al 47,6%

# %%
anios = [2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022]
data = names_frequency[names_frequency["anio"].isin(anios)]

names =  data.groupby("sexo").sum()

sns.set(style="whitegrid")
plt.figure(figsize=(8, 4))
sns.barplot(data=names, x="sexo", y='cantidad', palette="flare")
plt.xlabel('Sexo')
plt.ylabel('Cantidad')
plt.title('Cantidad de nacimientos por sexo')
plt.show()

names = names_frequency.groupby("sexo").sum()
total_sexo = names_frequency["cantidad"].sum()
names["porcentaje"] = (names["cantidad"] / total_sexo) * 100

plt.pie(names["porcentaje"].values, labels=names.index, autopct='%1.1f%%')
plt.title('Porcentaje de Nacimientos por Sexo')
plt.show()
# Out:
# /tmp/ipython-input-14-2952501391.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=names, x="sexo", y='cantidad', palette="flare")

# %% [markdown]
# **Grafico 3:**En el siguiente grafico muestra un desgloce de los años y que genero predomino en esos años. Podemos ver que en los primeros años se ve un marcado numero de nacimientos del sexo masculino y este va decreciendo hasta llegar al 2019 donde este se iguala, los años siguientes el sexo femenino va superando al otro sexo en cuestion.

# %%
anios = [2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022]
data = names_frequency[names_frequency["anio"].isin(anios)]

data =  data.groupby(["sexo","anio"]).sum()

sns.barplot(data=data, x="anio", y='cantidad', hue='sexo')
plt.xlabel('Año')
plt.ylabel('Cantidad')
plt.title('Cantidad de Nacimientos por Año y Sexo')
plt.show()

# %% [markdown]
# **Grafico 4:**En el siguiente grafico podemos observar un desgloce de los nacimientos entre 2012 al 2022 en las diferente provincias que comprende la Argentina. Podemos observar que, como el grafico 2 se ve un aumento y un decenso en los nacimientos en la mayoria de las de las provincias. Las 3 provincias que tuvieron la mayoria de nacimientos fueron Buenos Aires, Cordoba y Santa Fe.

# %%
tabla = births.pivot_table(index='provincia_nombre', columns='anio', values='nacimientos_cantidad', fill_value=0)

plt.figure(figsize=(20, 10))
sns.heatmap(tabla, cmap="YlOrBr", annot=True, fmt=".0f")
plt.title("Nacimientos por Provincia y Año")
plt.xlabel("Año")
plt.ylabel("Provincia")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Grafico 5:**En el siguiente grafico podemos observar que porcentaje en los años tomados en los datos equivalen los nacimientos en cada provincia. Predominando notablemente en la provincia de Buenos Aires

# %%
nacimientos_cantidad_total = births['nacimientos_cantidad'].sum()
df = births.groupby("provincia_nombre").sum()
df['porcentaje'] = (df['nacimientos_cantidad'] / nacimientos_cantidad_total) * 100
data = df.sort_values(by='porcentaje', ascending=False )

plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")

sns.barplot(data=data, x="provincia_nombre", y='porcentaje',palette='crest')
plt.xlabel('Provincia')
plt.ylabel('Porcentaje de nacimiento')
plt.yticks(ticks=range(0,40,2))
plt.xticks(rotation=90)
plt.title('Porcentaje de Nacimientos por Provincia')
plt.show()
# Out:
# /tmp/ipython-input-25-1522102411.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data, x="provincia_nombre", y='porcentaje',palette='crest')

# %% [markdown]
# **Grafico 6:**En el siguiente grafico podemos observar el total de los nacimientos entre el 2012 y 2022 por deparatamentos en la provincia del chaco, viendo que los 3 departamentos que poseen la mayor cantidad son San Fernando, General Guemes y Comandante Fernadez.

# %%
df = births[births["provincia_nombre"] == "Chaco"]
df = df.groupby(["departamento_nombre","anio"]).sum().sort_values(by='nacimientos_cantidad', ascending=False)

sns.set(style="whitegrid")
plt.figure(figsize=(12, 6))

sns.barplot(data=df, x="departamento_nombre", y='nacimientos_cantidad',palette='crest')
plt.xlabel('Departamento')
plt.ylabel('Nacimientos')
plt.xticks(rotation=90)
plt.title('Nacimientos por Departamento en Chaco entre el 2012 y 2022')
plt.show()
# Out:
# /tmp/ipython-input-16-1663612836.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x="departamento_nombre", y='nacimientos_cantidad',palette='crest')

# %% [markdown]
# **Grafico 6:**En el siguiente grafico podemos observar la ditribucion de sexo en nacidos entre el 2012 y 2022 por provincias

# %%
data = names_frequency.groupby(["sexo","nombre_provincia"]).sum()

sns.set(style="whitegrid")
plt.figure(figsize=(12, 6))

sns.barplot(data=data, x="nombre_provincia", y='cantidad', hue='sexo')
plt.xlabel('Provincia')
plt.ylabel('Cantidad')
plt.xticks(rotation=90)
plt.title('Cantidad de Nacimientos por Provincia y Sexo')
plt.show()

# %% [markdown]
# **Grafico 8:**En el siguiente grafico podemos observar una correlacion bastante alta entre los primeros años, tambien podemos observar que los años estan relacionados entre si, los datos de cada año se asemejan.

# %%
pivot = births.pivot_table(index='provincia_nombre', columns='anio', values='nacimientos_cantidad', fill_value=0)
correlatividad = pivot.corr()

plt.figure(figsize=(12, 6))
sns.heatmap(correlatividad, annot=True, cmap='YlOrBr')
plt.show()

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# En el presente analisis de los datos podemos ver las siguientes cosas
#
#
# 1. Se muestra un alza de nacimientos hasta el 2014 y posteriormente un decenso significativo en los nacimientos.
# 2.   Este desenso y crecimiento se ve tanto a nivel nacional como por provincia individualmente.
# 3.   Tambien se analizó el genero de cada nacimiento en a nivel total reflejando mas nacimientos del genero masculino que del femenino pero con poca diferencia entre ambos.
# 4. Se observo que en el rango de años analizados hay una tendencia decreciente de nacimientos del sexo masculino y llegando al 2019 este se igual con el femenino. A partir de ese año empiza a predominar el femenino sobre el masculino.
# 5. Desglozando por provincia en general vemos que el genero masculono predomina sobre el femenido en la mayoria de las provincias  y en solo 4 provincias esto no es asi.
#
#
#
# Podemos llegar a las siguientes hipotesis con respecto a los datos obtenidos.
# 1. El decenso de nacimientos puede esta ligado a:
#     *. Situacion economica de pais, la personas concideran que criar a un hijo es costoso o piensan que no podran darle todos los gastos que requieran
#     *. Cambios en el pensamiento de las personas, las pesonas poseen menor presion social para tener un hijo y priorizan su desarrollo personal antes que formar una familia.
#     *. Disponibiliad de metodos anticonceptivos, las personas usa estos tantos para prevenir enfermedades y a su vez evitar la concepcion de un hijo.
#
# 2. Con respecto a los diferentes sexos entre los nacidos podemos decir que el decenso que se persive en los graficos puede estar ligado a cambios geneticos debido a las mezclas de genes en diferentes generaciones.
